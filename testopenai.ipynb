# %%
from openai import OpenAI
from dotenv import load_dotenv

# %%
import os
client = OpenAI(
  api_key=os.environ['OPENAI_API_KEY'],  # this is also the default, it can be omitted
)

# %%
# !pip show openai
# Out:
# Name: openai
# Version: 1.26.0
# Summary: The official Python library for the openai API
# Home-page:
# Author:
# Author-email: OpenAI <support@openai.com>
# License:
# Location: d:\openai_practice\openaienv\lib\site-packages
# Requires: anyio, distro, httpx, pydantic, sniffio, tqdm, typing-extensions
# Required-by:

# %%
import pandas as pd
pd.DataFrame(client.models.list())
# Out:
#                                     0                      1                2  \
# 0                      (id, dall-e-3)  (created, 1698785189)  (object, model)
# 1                     (id, whisper-1)  (created, 1677532384)  (object, model)
# 2                   (id, davinci-002)  (created, 1692634301)  (object, model)
# 3                      (id, dall-e-2)  (created, 1698798177)  (object, model)
# 4             (id, gpt-3.5-turbo-16k)  (created, 1683758102)  (object, model)
# 5                 (id, tts-1-hd-1106)  (created, 1699053533)  (object, model)
# 6                      (id, tts-1-hd)  (created, 1699046015)  (object, model)
# 7                         (id, gpt-4)  (created, 1687882411)  (object, model)
# 8        (id, gpt-4-turbo-2024-04-09)  (created, 1712601677)  (object, model)
# 9                    (id, gpt-4-0613)  (created, 1686588896)  (object, model)
# 10                  (id, gpt-4-turbo)  (created, 1712361441)  (object, model)
# 11           (id, gpt-3.5-turbo-1106)  (created, 1698959748)  (object, model)
# 12         (id, gpt-4-vision-preview)  (created, 1698894917)  (object, model)
# 13  (id, gpt-3.5-turbo-instruct-0914)  (created, 1694122472)  (object, model)
# 14       (id, gpt-3.5-turbo-instruct)  (created, 1692901427)  (object, model)
# 15    (id, gpt-4-1106-vision-preview)  (created, 1711473033)  (object, model)
# 16                        (id, tts-1)  (created, 1681940951)  (object, model)
# 17           (id, gpt-3.5-turbo-0301)  (created, 1677649963)  (object, model)
# 18                  (id, babbage-002)  (created, 1692634615)  (object, model)
# 19                   (id, tts-1-1106)  (created, 1699053241)  (object, model)
# 20       (id, text-embedding-3-large)  (created, 1705953180)  (object, model)
# 21       (id, text-embedding-3-small)  (created, 1705948997)  (object, model)
# 22           (id, gpt-4-1106-preview)  (created, 1698957206)  (object, model)
# 23           (id, gpt-3.5-turbo-0613)  (created, 1686587434)  (object, model)
# 24       (id, text-embedding-ada-002)  (created, 1671217299)  (object, model)
# 25           (id, gpt-3.5-turbo-0125)  (created, 1706048358)  (object, model)
# 26          (id, gpt-4-turbo-preview)  (created, 1706037777)  (object, model)
# 27                (id, gpt-3.5-turbo)  (created, 1677610602)  (object, model)
# 28       (id, gpt-3.5-turbo-16k-0613)  (created, 1685474247)  (object, model)
# 29           (id, gpt-4-0125-preview)  (created, 1706037612)  (object, model)
#
#                               3
# 0            (owned_by, system)
# 1   (owned_by, openai-internal)
# 2            (owned_by, system)
# 3            (owned_by, system)
# 4   (owned_by, openai-internal)
# 5            (owned_by, system)
# 6            (owned_by, system)
# 7            (owned_by, openai)
# 8            (owned_by, system)
# 9            (owned_by, openai)
# 10           (owned_by, system)
# 11           (owned_by, system)
# 12           (owned_by, system)
# 13           (owned_by, system)
# 14           (owned_by, system)
# 15           (owned_by, system)
# 16  (owned_by, openai-internal)
# 17           (owned_by, openai)
# 18           (owned_by, system)
# 19           (owned_by, system)
# 20           (owned_by, system)
# 21           (owned_by, system)
# 22           (owned_by, system)
# 23           (owned_by, openai)
# 24  (owned_by, openai-internal)
# 25           (owned_by, system)
# 26           (owned_by, system)
# 27           (owned_by, openai)
# 28           (owned_by, openai)
# 29           (owned_by, system)

# %%
# Completion API...
response = client.completions.create(
    model="gpt-3.5-turbo-instruct",
    prompt="Explain Machine learning to a 5 years old",
    max_tokens = 10
)

# %%
response
# Out:
# Completion(id='cmpl-9MX3eTAn4zF8vnXiRaOIcHo0uzl7E', choices=[CompletionChoice(finish_reason='length', index=0, logprobs=None, text='\n\nMachine learning is like having a really smart')], created=1715157318, model='gpt-3.5-turbo-instruct', object='text_completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=10, prompt_tokens=10, total_tokens=20))
